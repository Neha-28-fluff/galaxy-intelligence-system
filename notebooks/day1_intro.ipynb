# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha-28-fluff/galaxy-intelligence-system/blob/main/notebooks/day1_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Galaxy Image ML Project: Day 1 Kickoff

# %% [markdown]
# ###Goal:
# ###Build a multi-faceted ML system to:
#
#
#
# 1.   Classify galaxy images by shape
# 2.   Predict redshift distance from images/data
# 1.   Detect galaxy anomalies/outliers
# 2.   Map galaxy images to similar Pokémon by color/visual features (for fun/visualization)
